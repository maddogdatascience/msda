# %% [markdown]
# # Getting Started with IPython Notebooks
#
# ## Why IPython?

# %% [markdown]
# IPython "encourages an *execute-explore* workflow instead of the typical *edit-compile-run* workflow of many other programming languages."  Wes McKinney, *Python for Data Analysis*.
#
# [This cell is configured to use **Markdown** language (also used by RStudio, yay!).  You can learn more about Markdown here: http://daringfireball.net/projects/markdown/]
#
# The following short video provides a good overview of Python's motivation and functionality.  Brian Granger is one of the core developers on the IPython project.

# %%
from IPython.lib.display import YouTubeVideo
YouTubeVideo('nRHBdkxVn48')
# Out:
#             <iframe
#                 width="400"
#                 height="300"
#                 src="http://www.youtube.com/embed/nRHBdkxVn48"
#                 frameborder="0"
#                 allowfullscreen
#             ></iframe>

# %% [markdown]
# # Graph Plotting
#
# Here is a short graphing example from Fernando Perez's 40 minute PyCon talk on IPython, available here:  https://www.youtube.com/watch?v=26wgEsg9Mcc.  Fernando Perez is the principal creator of Python.  [The first third or so of his talk are an interesting overview of the history; if you're time constrained, the demos start at 14:30].

# %%
x = linspace(0, 3*pi, 500)
plot(x, sin(x**2))
title('A simple chirp!')

# %% [markdown]
# You can learn about **Markdown** here:  http://daringfireball.net/projects/markdown/syntax
